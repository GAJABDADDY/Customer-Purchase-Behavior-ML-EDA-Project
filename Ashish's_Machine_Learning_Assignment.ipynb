# %% [markdown]
# <a href="https://colab.research.google.com/github/GAJABDADDY/Customer-Purchase-Behavior-ML-EDA-Project/blob/main/Ashish's_Machine_Learning_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**ML Case Study**

# %% [markdown]
# ###**About the Project:**

# %% [markdown]
# Welcome to the realm of hands-on machine learning! In this open-ended ML Case Study, you have the opportunity to explore the vast landscape of machine learning applications across diverse industries. Your mission is to select one project from the list of projects given below in the cheat sheet or propose your own project idea that aligns with your interests and aspirations. This project is your canvas to apply your machine learning skills, experiment with various algorithms, and demonstrate your ability to tackle real-world challenges using data-driven insights. Through this project, you'll showcase your autonomy, creativity, and technical prowess as you contribute to shaping the future with data-driven solutions.

# %% [markdown]
# ###**Skills Required:**

# %% [markdown]
# 1. Proficiency in Python programming.
# 2. Familiarity with data manipulation libraries (e.g., pandas,numpy).
# 3. Knowledge of data visualisation tools (e.g., matplotlib, seaborn).
# 4. Understanding of machine learning concepts and clustering algorithms (e.g., K-means).
# 5. Ability to analyse and interpret data insights.
# 6. Strong report writing and presentation skills.

# %% [markdown]
# ###**Deliverables:**

# %% [markdown]
# Case Study Colab Notebook: Students should submit a Google colab (.ipynb) showcasing their data analysis process, including loading the dataset, data cleaning, exploration, visualisations, modelling and preliminary insights.

# %% [markdown]
# ###**Rubrics for Assessment:**

# %% [markdown]
# 1. **Data Exploration and Preprocessing:**
#   Correct loading of data and handling of missing values.
#   Effective identification and handling of outliers if present.
#
# 2. **Feature Engineering:**
#   Appropriate calculation of metrics and creation of new features.
#   Clear explanations for the chosen feature engineering strategies.
#
# 3. **Customer Segmentation:**
#   Proper selection and application of the clustering algorithm.
#   Clear justification for the chosen number of clusters.
#   Accurate visualisation of customer segments.
#
# 4. **Interpretation and Analysis:**
#   Thorough analysis of customer segments' characteristics.
#   Meaningful insights and observations drawn from the analysis.
#   Demonstration of critical thinking and depth of understanding.
#
# 5. **Recommendations:**
#   Relevant and actionable recommendations for marketing strategies.
#   Alignment of recommendations with the analysis.
#
# 6. **Visualisations and Reporting:**
#   Effective visualisations that enhance the understanding of insights.
#   Clear, concise, and well-structured report or presentation.

# %% [markdown]
# # **Customer Purchase Behavior**

# %% [markdown]
# ##**1. Problem Statement:**

# %% [markdown]
# Imagine yourself as a freelance data scientist ready for the next project adventure.
#
# Your mission is to analyze the provided dataset containing Customer information and Purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates.
#
# Your project will be a testament to your adaptability, curiosity, and aptitude for machine learning.

# %% [markdown]
# 1.1. **Type of Problem**:
#
#   Since we are dealing with Customer Purchase Behavior, this seems like a classic case for a **Supervised Learning** problem. We have labeled data indicating whether customers accepted or rejected offers, and we want to predict the future acceptance rates based on various features.
#
# 1.2. **Business Objective**:
#
#   The primary objective is to **optimize marketing efforts to increase offer acceptance rates.** The desired outcome would be a model that accurately predicts which customers are more likely to accept offers, allowing the company to target those customers more effectively.
#
# 1.3. **Constraints & Limitations**:
#    - **Computational Power**: Ensuring the ML algorithms can run efficiently with the available computational resources.
#    - **Budget**: Considering the budget constraints for acquiring additional computational power or data.
#    - **Data Availability**: Ensuring we have enough historical data on customer purchases and offer acceptance.
#    - **Obstacles**: Addressing any potential challenges such as data quality issues or privacy concerns.
#
# 1.4. **Evaluation Metrics**:
#    - **Optimization Required**: Optimizing the model for better Accuracy.
#    - **KPIs Tracking**: Tracking Key Performance Indicators (KPIs) such as offer acceptance rates, conversion rates, and ROI.
#    - **Required Testing**: Performing rigorous testing using cross-validation techniques to ensure the model's generalizability.
#
# 1.5. **Relevancy to the Target Audience**:
#   The model's predictions should be timely and actionable, allowing the marketing team to act quickly on insights. Speed of prediction can be crucial for real-time marketing campaigns.
#
# 1.6. **Data Availability**:
#   Ensuring ease of data collection and identifying the necessary features required for accurate predictions. We may need demographic data, purchase history, interaction with previous offers, etc.
#
# 1.7. **Scope of the Solution**:
#   Defining the model's capabilities clearly to manage expectations. The solution should be capable of providing actionable insights, segmenting customers effectively, and adapting to changing trends in customer behavior.

# %% [markdown]
# ##**2. Data Collection:**

# %% [markdown]
# ###2.1. **About the Dataset:**

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ###2.2. **Importing the Libraries:**

# %%
#Importing NumPy library
import numpy as np

#Importing Pandas library
import pandas as pd

#Importing Matplotlib and Seaborn library
import seaborn as sns
import matplotlib.pyplot as plt

#Importing Google Drive Package from google.colab library
from google.colab import drive
drive.mount('/content/drive') #mounting google drive

#We'll import the rest of the libraries later on..
# Out:
# Mounted at /content/drive

# %%
# To help with reading and manipulating data
import pandas as pd
import numpy as np

# To help with data visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns


# To help with model building
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    AdaBoostClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier,
    BaggingClassifier,
)

# To get different metric scores, and split data
from sklearn import metrics
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import (
    f1_score,
    accuracy_score,
    recall_score,
    precision_score,
    confusion_matrix,
    roc_auc_score
)


# To be used for data scaling and one hot encoding
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder

# To be used for tuning the model
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# To be used for creating pipelines and personalizing them
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# To define maximum number of columns to be displayed in a dataframe
pd.set_option("display.max_columns", None)

# To supress scientific notations for a dataframe
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# To supress warnings
import warnings

warnings.filterwarnings("ignore")

# This will help in making the Python code more structured automatically (good coding practice)
#%load_ext nb_black

# %% [markdown]
# ###2.3. **Importing the Dataset:**

# %%
# Load Dataset

filepath="/content/drive/MyDrive/Machine Learning Assignment/Superstore Marketing Data - Sheet1.csv"
df=pd.read_csv(filepath)

# %% [markdown]
# ###2.4. **Data Types:**

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# ###2.5. **Data Quality:**

# %%
# First 5 rows of the dataset:

df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status    Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced 84835.000        0         0
# 1      1        1961  Graduation         Single 57091.000        0         0
# 2  10476        1958  Graduation        Married 67267.000        0         1
# 3   1386        1967  Graduation       Together 32474.000        1         1
# 4   5371        1989  Graduation         Single 21474.000        1         0
#
#   Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0   6/16/2014        0       189        104              379              111
# 1   6/15/2014        0       464          5               64                7
# 2   5/13/2014        0       134         11               59               15
# 3    ########        0        10          0                1                0
# 4    ########        0         6         16               24               11
#
# ...

# %% [markdown]
# From the following dataset information, we can deduce that:
#
# 1.  All the columns have 2240 rows except for the column 'Income' which has 2216 non-null rows indicating 24 null rows.
#
# 2. We can also see there are some rows with '########' as the value in the 'Dt_Customer' column.
#
# 3. Missing values in the columns 'Dt_customer' and 'Income'.
#
# 4. Outlier in the column 'Income'.

# %% [markdown]
# All the Data Cleaning and Data transformation techniques will be performed in the next step.

# %% [markdown]
# ## **3. Data Processing:**

# %% [markdown]
# As we saw that only column 'Income' contains 24 null rows and the rest have consistent data, thus, we'll just replace the empty rows with 'na'.
#
# Below, we have shown a heatmap visualisation showing the amount of missing values in the dataset.

# %% [markdown]
# ###3.1. **NA Replacement:**

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df.fillna('na')
# Out:
#          Id  Year_Birth   Education Marital_Status    Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced 84835.000        0
# 1         1        1961  Graduation         Single 57091.000        0
# 2     10476        1958  Graduation        Married 67267.000        0
# 3      1386        1967  Graduation       Together 32474.000        1
# 4      5371        1989  Graduation         Single 21474.000        1
# ...     ...         ...         ...            ...       ...      ...
# 2235  10142        1976         PhD       Divorced 66476.000        0
# 2236   5263        1977    2n Cycle        Married 31056.000        1
# 2237     22        1976  Graduation       Divorced 46310.000        1
# 2238    528        1978  Graduation        Married 65819.000        0
# 2239   4070        1969         PhD        Married 94871.000        0
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %% [markdown]
# Here, the .fillna() method converts all the null values to the specified parameter. This in turn ensures the data is more user-friendly and in a better readable format.

# %% [markdown]
# ###3.2. **Imputation Method:**

# %% [markdown]
# We can also there are some rows with '########' as the value in the 'Dt_Customer' column. Let's see..

# %%
count=0
for i in df['Dt_Customer']:
  if i=='########':
    count+=1
  else:
    pass
print(count)
# Out:
# 916

# %% [markdown]
# As we can see there are 916 rows with missing date values, we will need to first convert the 'Dt_Customer' column to datetime datatype to fill in those missing values with an imputation method.

# %% [markdown]
# To first convert to datetime, we need to take care of '########' values present in the 'Dt_Customer' column.

# %%
df['Dt_Customer'] = df['Dt_Customer'].replace('########', pd.NaT) #NaT stands for  'Not a Time' in pandas

# %%
df['Dt_Customer'].head()
# Out:
# 0   2014-06-16
# 1   2014-06-15
# 2   2014-05-13
# 3   2014-05-13
# 4   2014-05-13
# Name: Dt_Customer, dtype: datetime64[ns]

# %% [markdown]
# We can see the # values have been replaced with NaT values. Now, we can proceed to change the datatype to datetime.

# %%
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'], errors='coerce') #any errors will be converted to NaT values

# %% [markdown]
# Now, we'll check if there are any remaing invalid values:

# %%
# Check for remaining invalid values

invalid_values = df[df['Dt_Customer'].isnull()]['Dt_Customer']
print("Invalid values after conversion:", invalid_values)
# Out:
# Invalid values after conversion: 3      NaT
# 4      NaT
# 8      NaT
# 9      NaT
# 11     NaT
#         ..
# 2231   NaT
# 2232   NaT
# 2235   NaT
# 2237   NaT
# 2239   NaT
# Name: Dt_Customer, Length: 916, dtype: datetime64[ns]

# %% [markdown]
# We found 3 invalid values after conversion but as they have been also to converted to 'NaT ' values with the help of 'Coerce' parameter, we'll continue with applying the imputation method.

# %% [markdown]
# **Imputation Methods:**
#
# Imputation methods are techniques used to fill in missing values in a dataset with estimated values. These methods are particularly useful when dealing with incomplete datasets, as missing data can adversely affect the performance of machine learning models and statistical analyses.
#
# We are going to use the linear interpolation method here to assume missing values for the dates.
#
# **Linear Interpolation:**
#
# Forward Fill (or Backward Fill):
#
# Method: Fill missing dates with the last observed date (forward fill) along the same column.

# %%
# Perform linear interpolation to fill missing dates using forward fill
df['Dt_Customer'] = df['Dt_Customer'].interpolate(method='pad')  # or method='ffill'

# %% [markdown]
# As you can see, we have performed the ff (Forward Fill) interpolation imputation method and filled the missing dates in the column 'Dt_Customer'.
#
# Checking the remaining no. of NaN values:

# %%
nan_count = df['Dt_Customer'].isna().sum()
print(nan_count)
# Out:
# 0

# %%
df['Dt_Customer']
# Out:
# 0      2014-06-16
# 1      2014-06-15
# 2      2014-05-13
# 3      2014-05-13
# 4      2014-05-13
#           ...
# 2235   2013-09-17
# 2236   2013-01-22
# 2237   2013-01-22
# 2238   2012-11-29
# 2239   2012-11-29
# Name: Dt_Customer, Length: 2240, dtype: datetime64[ns]

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# Although we have cleared all the missing values for the column 'Dt_Customer', we still have some missing values for the column 'Income'.
#
# First, let's check the no. of missing values in the column 'Income'.

# %%
nan_count = df['Income'].isna().sum()
print(nan_count)
# Out:
# 24

# %% [markdown]
# As there are only 24 missing values, we'll use a simple imputation method called the 'Median Imputation' as they'll replace missing income values with the mean of the existing income values. As the median value can be skewed if there is any outlier, let's first check if there is any..

# %% [markdown]
# ###3.3. **Handling Outliers:**

# %%
df['Income'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Since there are several values outside the whisker, it may contain necessary information and removing them may result in data inconsistencies.
#
# But..
#
# We can see a single value greater than 600000 while the rest lie between 100000-200000.. Hence, we will ignore that value by creating a threshhold so that the median value is not skewed.

# %%
# Identify and handle outliers (e.g., values above 3 standard deviations from the mean)
#mean_income = df['Income'].mean()
income_outlier = 600000

# Exclude outliers from the income data
income_no_outliers = df['Income'][df['Income'] <= income_outlier]

# Calculate median excluding outliers
median_income_no_outliers = np.median(income_no_outliers)

# Fill missing income values with adjusted median (excluding outliers)
df['Income'].fillna(median_income_no_outliers, inplace=True)

# %% [markdown]
# We have successfully filled the missing values with the median value of the column 'Income'.
#
# Now, let's check if there are any missing values or not..

# %%
nan_count = df['Income'].isna().sum()
print(nan_count)
# Out:
# 0

# %% [markdown]
# As we can see, there hasn't been any outlier value created..
#
# Finally, we'll delete the row with an outlier value in the column 'Income' as it will skew the measures of central tendency by a lot.

# %%
# Drop rows with 'Income' greater than 600000
df = df[df['Income'] <= 600000]

total_rows = len(df['Income'])
print(total_rows)
# Out:
# 2239

# %%
print(df['Income'].max()) #Showing the current max value of the column 'Income'.
# Out:
# 162397.0

# %% [markdown]
# As there are no missing values, let's check through the box plot chart once again to see if there was any outlier value created while calculating the median..

# %%
df['Income'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Since the total no. of rows has gone from 2240 to 2239, we can say that the outlier value has been removed and our dataset is now completely free from any ouliers or missing values!!
#
# Let's check the heatmap once again to see if there are any missing values left.

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# From the above graph, We can see that there are no outliers or any missing values left in the dataset for us to clean. Our Data Cleaning process has been completed.

# %% [markdown]
# ###3.4. **Feature Engineering:**

# %% [markdown]
# Feature engineering specifically focuses on transforming and manipulating the features i.e columns of the dataset to make them more informative and suitable for the learning algorithm.

# %% [markdown]
# We can drop the column - Id as it is unique for each customer and will not add value to the model.

# %%
# Dropping column - Id
df.drop(columns=["Id"], inplace=True)

# %% [markdown]
# We have already converted Dt_Customer to a datetime object during imputation method.

# %% [markdown]
# ####**Age:**

# %% [markdown]
# To calculate age, we'll subtract the year 2021 because variables account for the last 2 years and we have customers registered till 2014 only.

# %%
# We need to convert strings values to dates first to use subtraction
df["Age"] = 2021 - pd.to_datetime(df["Year_Birth"], format="%Y").apply(lambda x: x.year)

df["Age"].sort_values()
# Out:
# 562      25
# 1824     25
# 697      26
# 1468     26
# 964      26
#        ...
# 1740     80
# 2171     81
# 2233    121
# 827     122
# 513     128
# Name: Age, Length: 2239, dtype: int64

# %% [markdown]
# * We can see that there are few observations with ages greater than 100 which is highly unlikely to be true.
#
# * We can drop the observations with age greater than 100

# %%
df[df["Age"] > 100]
# Out:
#       Year_Birth Education Marital_Status    Income  Kidhome  Teenhome  \
# 513         1893  2n Cycle         Single 60182.000        0         1
# 827         1899       PhD       Together 83532.000        0         0
# 2233        1900  2n Cycle       Divorced 36640.000        1         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 513   2014-05-17       23         8          0                5
# 827   2013-09-26       36       755        144              562
# 2233  2013-09-26       99        15          6                8
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 513                 7                 0             2                  1
# 827               104                64           224                  1
# 2233                7                 4            25                  1
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ...

# %% [markdown]
# The Year_Birth for these 3 observations seems to be incorrect.
#
# Replacing them with some other values might not be the best thing to do
#
# Thus, We will drop these 3 observations

# %%
# Dropping the 3 observations with age > 100
df.drop(df[df["Age"] > 100].index, inplace=True)

# %% [markdown]
# ####Using **Dt_Customer** to add additional features to the data:

# %%
# Extracting registration year from the date
df["Reg_year"] = df["Dt_Customer"].apply(lambda x: x.year)

# Extracting registration quarter from the date
df["Reg_quarter"] = df["Dt_Customer"].apply(lambda x: x.quarter)

# Extracting registration month from the date
df["Reg_month"] = df["Dt_Customer"].apply(lambda x: x.month)

# Extracting registration week from the date
df["Reg_week"] = df["Dt_Customer"].apply(lambda x: x.day // 7)

# %%
df.head()
# Out:
#    Year_Birth   Education Marital_Status    Income  Kidhome  Teenhome  \
# 0        1970  Graduation       Divorced 84835.000        0         0
# 1        1961  Graduation         Single 57091.000        0         0
# 2        1958  Graduation        Married 67267.000        0         1
# 3        1967  Graduation       Together 32474.000        1         1
# 4        1989  Graduation         Single 21474.000        1         0
#
#   Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0  2014-06-16        0       189        104              379              111
# 1  2014-06-15        0       464          5               64                7
# 2  2014-05-13        0       134         11               59               15
# 3  2014-05-13        0        10          0                1                0
# 4  2014-05-13        0         6         16               24               11
#
#    MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %% [markdown]
# Now, Let's check the count of each unique category in each of the categorical variables present in the dataset.

# %%
# Making a list of all categorical variables
cat_col = [
    "Education",
    "Marital_Status",
    "Kidhome",
    "Teenhome",
    "Complain",
    "Response",
    "Reg_year",
    "Reg_quarter",
    "Reg_month",
    "Reg_week",
]

# Printing number of count of each unique value in each column
for column in cat_col:
    print(df[column].value_counts())
    print("-" * 40)
# Out:
# Education
# Graduation    1126
# PhD            485
# Master         370
# 2n Cycle       201
# Basic           54
# Name: count, dtype: int64
# ----------------------------------------
# Marital_Status
# Married     864
# Together    578
# Single      479
# Divorced    231
# Widow        77
# Alone         3
# YOLO          2
# Absurd        2
# Name: count, dtype: int64
# ----------------------------------------
# Kidhome
# 0    1291
# 1     897
# 2      48
# Name: count, dtype: int64
# ----------------------------------------
# Teenhome
# 0    1155
# 1    1029
# 2      52
# Name: count, dtype: int64
# ----------------------------------------
# Complain
# 0    2216
# 1      20
# Name: count, dtype: int64
# ----------------------------------------
# Response
# 0    1902
# 1     334
# Name: count, dtype: int64
# ----------------------------------------
# Reg_year
# 2013    1195
# 2014     561
# 2012     480
# Name: count, dtype: int64
# ----------------------------------------
# ...

# %% [markdown]
# In education, 2n cycle and Master means the same thing. We can combine these two categories to avoid unnecessary cluttering.
#
# There are many categories in marital status. We can combine the categories 'Alone', 'Absurd' and 'YOLO' with 'Single' and 'Together' categories with 'Married'.
#
# There are only 20 customers who complained in the last two years.
# In 'Response' we have 1902 observations for the 0 class but only 334 observations for class 1.
#
# There are only three years in the customer registration data.

# %% [markdown]
# Replacing 2n Cycle with Master:

# %%
# Replacing 2n Cycle with Master
df["Education"] = df["Education"].replace("2n Cycle", "Master")

# %% [markdown]
# Replacing YOLO, Alone, Absurd with single and Together with Married:

# %%
# Replacing YOLO, Alone, Absurd with single and Together with Married
df["Marital_Status"] = df["Marital_Status"].replace(["YOLO", "Alone", "Absurd"], "Single")
df["Marital_Status"] = df["Marital_Status"].replace(["Together"], "Married")

# %% [markdown]
# We will also add a column - total amount spent by each customer in the last 2 years

# %%
#Total Amount Spent:

df["Total_Amount_Spent"] = df[
    [
        "MntWines",
        "MntFruits",
        "MntMeatProducts",
        "MntFishProducts",
        "MntSweetProducts",
        "MntGoldProds",
    ]
].sum(axis=1)

# %% [markdown]
# ## **4. Exploratory Data Analysis (EDA):**

# %% [markdown]
# We will first define some functions which will help in better graph plots.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def histogram_boxplot(df, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    df: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=df, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a triangle will indicate the mean value of the column
    if bins:
        sns.histplot(
            data=df, x=feature, kde=kde, ax=ax_hist2, bins=bins
        )
    else:
        sns.histplot(
            data=df, x=feature, kde=kde, ax=ax_hist2
        )  # For histogram
    ax_hist2.axvline(
        df[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        df[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def labeled_barplot(df, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    df: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    plt.figure(figsize=(n + 2, 6) if n is not None else (len(df[feature].unique()) + 2, 6))
    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=df,
        x=feature,
        palette="Paired",
        order=df[feature].value_counts().index[:n],
    )

    for p in ax.patches:
        label = "{:.1f}%".format(100 * p.get_height() / len(df[feature])) if perc else p.get_height()
        x = p.get_x() + p.get_width() / 2
        y = p.get_height()
        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )

    plt.show()

# %%
# function to plot stacked bar chart


def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    df: dataframe
    predictor: independent variable
    target: target variable
    """
    count = df[predictor].nunique()
    sorter = df[target].value_counts().index[-1]
    tab1 = pd.crosstab(df[predictor], df[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(df[predictor], df[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left", frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %% [markdown]
# ###4.1. **Univariate Analysis:**

# %% [markdown]
# ####**1. Income**

# %%
# observations on Income
histogram_boxplot(df, "Income")

# %% [markdown]
# Since we had deleted the row with an outlier value of 666666, we can see that the column 'Income' is well distributed with average income being around 50000.

# %% [markdown]
# ####**2. MntMeatProducts**

# %%
# observations on MntMeatProducts
histogram_boxplot(df, "MntMeatProducts")

# %% [markdown]
# * The distribution for the amount spent on meat products is highly skewed to the right.
#
# * We can see that there are some extreme observations in the variable that can be considered as outliers as they very far from the rest of the values.
# We can cap the value of the variable to the next highest value.

# %%
# Checking 10 largest values of amount spend on meat products
df.MntMeatProducts.nlargest(10)
# Out:
# 325     1725
# 961     1725
# 497     1622
# 1213    1607
# 2204    1582
# 1921     984
# 53       981
# 994      974
# 2021     968
# 1338     961
# Name: MntMeatProducts, dtype: int64

# %%
df[df["MntMeatProducts"] > 1580]
# Out:
#       Year_Birth   Education Marital_Status     Income  Kidhome  Teenhome  \
# 325         1977  Graduation        Married 157146.000        0         0
# 497         1982         PhD        Married 160803.000        0         0
# 961         1979  Graduation        Married   2447.000        1         0
# 1213        1978      Master        Married  51373.000        0         0
# 2204        1973         PhD        Married 157243.000        0         1
#
#      Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 325   2013-04-29       13         1          0             1725
# 497   2012-08-26       21        55         16             1622
# 961   2013-03-17       42         1          1             1725
# 1213  2012-08-13       53        32          2             1607
# 2204  2014-05-28       98        20          2             1582
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# ...

# %% [markdown]
# The values for MntMeatProducts for these 5 observations need not be incorrect
# So, dropping them will lead us to loss of information
# Let's cap them with next highest value i.e 984.

# %%
# Capping values for amount spent on meat products at next highest value i.e. 984
df["MntMeatProducts"].clip(upper=984, inplace=True)

# %% [markdown]
# Here, the .clip() method uses the upper value to change any greater value to the clipped value.

# %% [markdown]
# ####**3. MntSweetProducts**

# %%
# observations on MntSweetProducts
histogram_boxplot(df, "MntSweetProducts")

# %% [markdown]
# * The distribution for the amount spent on sweet products is right-skewed
#
# * There is one observation to the right extreme which can be considered as an outlier.
#
# * We will not remove all such data points as they represent real market trends but we can cap some of the extreme values.

# %%
df[df["MntSweetProducts"] > 200]
# Out:
#      Year_Birth   Education Marital_Status     Income  Kidhome  Teenhome  \
# 210        1945         PhD         Single 113734.000        0         0
# 449        1986  Graduation         Single  51373.000        1         0
#
#     Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 210  2014-05-28        9         6          2                3
# 449  2013-02-20       19         5          1                3
#
#      MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 210                1               262             3                  0
# 449                3               263           362                  0
#
#      NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 210               27                    0                  0
# 449               27                    0                  0
#
#      NumWebVisitsMonth  Response  Complain  Age  Reg_year  Reg_quarter  \
# 210                  1         0         0   76      2014            2
# ...

# %% [markdown]
# * The values for MntSweetProducts for these 2 observations need not be incorrect
#
# * Thus, dropping them will lead us to loss of information. So,
# Let's cap them with next highest value

# %%
# Capping values for amount spent on sweet products at 198
df["MntSweetProducts"].clip(upper=198, inplace=True)

# %% [markdown]
# ####**4. MntGoldProds**

# %%
# observations on MntGoldProds
histogram_boxplot(df, "MntGoldProds")

# %% [markdown]
# * The distribution for the amount spent on gold products is right-skewed
#
# * There are some outliers in the amount spent on gold products. We will not remove all such data points as they represent real market trends but we can cap some of the extreme values.

# %%
df[df["MntGoldProds"] > 250]
# Out:
#       Year_Birth   Education Marital_Status    Income  Kidhome  Teenhome  \
# 14          1969  Graduation        Married  4428.000        0         1
# 60          1982      Master         Single  6560.000        0         0
# 449         1986  Graduation         Single 51373.000        1         0
# 2063        1966         PhD         Single  7144.000        0         2
#
#      Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 14    2013-10-16        0        16          4               12
# 60    2014-03-29        2        67         11               26
# 449   2013-02-20       19         5          1                3
# 2063  2014-02-24       92        81          4               33
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 14                  2                 4           321                  0
# 60                  4                 3           262                  0
# ...

# %% [markdown]
# The values for MntGoldProds for these 4 observations need not be incorrect.
#
# Therefore, dropping them will lead us to loss of information.
#
# Thus, we will cap them with next highest value.

# %%
df["MntGoldProds"].clip(upper=250, inplace=True)

# %% [markdown]
# ####**5. MntWines**

# %%
# observations on MntWines
histogram_boxplot(df, "MntWines")

# %% [markdown]
# * The distribution for the amount spent on wines is highly skewed to the right.
# As the median of the distribution is less than 200, more than 50% of customers have spent less than 200 on wines.
#
# There are some outliers on the right end of the boxplot but we will not treat them as some variation is always expected in real-world scenarios for variables like amount spent.

# %% [markdown]
# ####**6. NumWebPurchases**

# %%
histogram_boxplot(df, "NumWebPurchases")

# %% [markdown]
# The median of the distribution is 4 i.e. 50% of customers have 4 or less than 4 web purchases.
#
# We can see that there are some extreme observations in the variable. We can cap these values to the next highest number of purchases.

# %%
df[df["NumWebPurchases"] > 15]
# Out:
#       Year_Birth   Education Marital_Status     Income  Kidhome  Teenhome  \
# 14          1969  Graduation        Married   4428.000        0         1
# 210         1945         PhD         Single 113734.000        0         0
# 449         1986  Graduation         Single  51373.000        1         0
# 2063        1966         PhD         Single   7144.000        0         2
#
#      Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 14    2013-10-16        0        16          4               12
# 210   2014-05-28        9         6          2                3
# 449   2013-02-20       19         5          1                3
# 2063  2014-02-24       92        81          4               33
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 14                  2                 4           250                  0
# 210                 1               198             3                  0
# ...

# %% [markdown]
# The values for NumWebPurchases for these 4 observations need not be incorrect.
#
# So, dropping them will lead us to loss of information
#
# Thus, we will cap them with next highest value.

# %%
# Capping values for number of web purchases at 11
df["NumWebPurchases"].clip(upper=11, inplace=True)

# %% [markdown]
# ####**7. NumWebVisitsMonth**

# %%
histogram_boxplot(df, "NumWebVisitsMonth")

# %% [markdown]
# The distribution for the number of visits in a month is skewed and has some outliers at the right end.
#
# We will not treat this as this represents a general market trend.

# %% [markdown]
# ####**8. NumCatalogPurchases**

# %%
# observations on NumCatalogPurchases
histogram_boxplot(df, "NumCatalogPurchases")

# %% [markdown]
# The most number of observations are for 0 catalog purchases.
#
# The median of the distribution is 2 i.e. 50% of customers have 2 or less than 2 catalog purchases.
#
# We can see that there is two extreme observation in the variable. We can cap these values to the next highest number of purchases.

# %%
df[df["NumCatalogPurchases"] > 15]
# Out:
#       Year_Birth   Education Marital_Status     Income  Kidhome  Teenhome  \
# 325         1977  Graduation        Married 157146.000        0         0
# 497         1982         PhD        Married 160803.000        0         0
# 961         1979  Graduation        Married   2447.000        1         0
# 2204        1973         PhD        Married 157243.000        0         1
#
#      Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# 325   2013-04-29       13         1          0              984
# 497   2012-08-26       21        55         16              984
# 961   2013-03-17       42         1          1              984
# 2204  2014-05-28       98        20          2              984
#
#       MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# 325                 2                 1             1                  0
# 497                17                 3             4                 15
# ...

# %%
# Capping values for number of catalog purchases at 11
df["NumCatalogPurchases"].clip(upper=11, inplace=True)

# %% [markdown]
# ####**9. Complain**

# %%
labeled_barplot(df, "Complain", perc=True)

# %% [markdown]
# Approx 99% of customers had no complaint in the last 2 years. This might be because the company provides good services or might be due to the lack of feedback options for customers.

# %% [markdown]
# ####**10. Teenhome**

# %%
labeled_barplot(df, "Teenhome", perc=True)

# %% [markdown]
# Majority of the customers i.e. ~52% customers have no teen at home.
#
# There are around 46% of customers with only 1 teen.
#
# There are very few customers, only ~2%, with a number of teens greater than 1

# %% [markdown]
# ####**11. Response**

# %%
# observations on Response
labeled_barplot(df, "Response", perc=True)

# %% [markdown]
# Approx 85% customer's response was **NO** in the last campaign.
#
# This shows that the distribution of classes in the target variable is imbalanced. We have only ~15% observations where response is **YES**.

# %% [markdown]
# ####**12. Age**

# %%
histogram_boxplot(df, "Age")

# %% [markdown]
# As per the boxplot, there are no outliers in the 'Age' variable.
#
# Age has a fairly normal distribution with approx equal mean and median.

# %% [markdown]
# ####**13. NumStorePurchases**

# %%
histogram_boxplot(df, "NumStorePurchases")

# %% [markdown]
# There are very few observations with less than 2 purchases from the store.
#
# Most of the customers have 4 or 5 purchases from the store.
#
# There are no outliers in this variable.

# %% [markdown]
# ####**14. NumDealsPurchases**

# %%
histogram_boxplot(df, "NumDealsPurchases")

# %% [markdown]
# Majority of the customers have 2 or less than 2 deal purchases.
#
# We can see that there some extreme observations in the variable. This represents the real market trend.

# %% [markdown]
# ####**15. Recency**

# %%
# observations on Recency
histogram_boxplot(df, "Recency")

# %% [markdown]
# There are no outliers in the 'Recency' variable.
#
# The distribution is fairly symmetric and uniformly distributed.

# %% [markdown]
# ####**16. MntFruits**

# %%
# observations on MntFruits
histogram_boxplot(df, "MntFruits")

# %% [markdown]
# The distribution for the amount spent on fruits is highly skewed to the right.
#
# As the median of the distribution is less than 20, more than 50% of customers have spent less than 20 on fruits.
#
# There are some outliers on the right end of the boxplot but we will not treat them as some variation is always expected in real-world scenarios for variables like amount spent.

# %% [markdown]
# ####**17. MntFishProducts**

# %%
# observations on MntFishProducts
histogram_boxplot(df, "MntFishProducts")

# %% [markdown]
# The distribution for the amount spent on fish products is right-skewed.
#
# There are some outliers on the right end in the boxplot but we will not treat them as this represents a real market trend that some customers spend more on fish products than others.

# %% [markdown]
# ####**18. Reg_week**

# %%
# observations on Registration week
labeled_barplot(df, "Reg_week", perc = True)

# %% [markdown]
# This shows that the number of registrations declines at the end of the month i.e. in the last two weeks.
#
# This can be because most people get salaries on the last day or first day of the month.

# %% [markdown]
# ####**19. Marita_Status**

# %%
# observations on Marital_Status
labeled_barplot(df, "Marital_Status",perc = True)

# %% [markdown]
# Majority of the customers are married comprising approx ~64% of total customers.

# %% [markdown]
# ####**20. Education**

# %%
# observations on Education
labeled_barplot(df, "Education",perc = True)

# %% [markdown]
# Education of approx ~50% of customers is at graduation level.
#
# Very few observations i.e. ~2% for customers with basic level education

# %% [markdown]
# ####**21. Kidhome**

# %%
# observations on Kidhome
labeled_barplot(df, "Kidhome",perc = True)

# %% [markdown]
# ~40% of customers have 1 kid and ~58% of customers have no kids at home.
#
# There are very few customers, approx 2%, with a number of kids greater than 1

# %% [markdown]
# ####**22. Reg_year**

# %%
# observations on Registration year
labeled_barplot(df, "Reg_year",perc = True)

# %% [markdown]
# The number of customers registered is highest in the year 2013.

# %% [markdown]
# ####**23. Reg_quarter**

# %%
# observations on Registration quarter
labeled_barplot(df, "Reg_quarter",perc = True)

# %% [markdown]
# There is no significant difference in the number of registrations for each quarter.
#
# The number of registrations is slightly higher for the 1st and the 4th quarter.
#
# This can be due to the festival season in these months. We'll explore this further by plotting the count of registration per month.

# %% [markdown]
# ####**24. Reg_month:**

# %%
# observations on Registration month
labeled_barplot(df, "Reg_month",perc = True)

# %% [markdown]
# This shows that the highest number of registration is in the months of winters i.e. March, May, August, October.
#
# There is approx 3% reduction in the number of registrations from June to July.

# %% [markdown]
# ###4.2. **Bivariate Analysis:**

# %% [markdown]
# Bivariate analysis involves the simultaneous analysis of two variables to determine if there is a relationship or correlation between them. This type of analysis is crucial in statistics, data science, and machine learning, as it helps in understanding how one variable affects another and in making predictions or drawing conclusions based on these relationships.

# %% [markdown]
# Following is the bivariate analysis for:

# %% [markdown]
# ####**MntWines, MntGoldProds, MntMeatProducts, MntFruits, MntFishProducts, MntSweetProducts**

# %%
cols = [
    "MntWines",
    "MntGoldProds",
    "MntMeatProducts",
    "MntFruits",
    "MntFishProducts",
    "MntSweetProducts",
]

plt.figure(figsize=(10, 10))

for i, variable in enumerate(cols):
    plt.subplot(3, 2, i + 1)
    sns.boxplot(x=df["Response"], y=df[variable], hue=df["Response"], palette="Set2")
    plt.tight_layout()
    plt.title(variable)

plt.show()

# %% [markdown]
# From the above graphs, we can see that in each plot, the customers who are spending more on any product are more likely to take the offer.

# %% [markdown]
# ####**Reg_year & Reg_month vs Total_Amount_Spent**

# %%
pd.pivot_table(
    data=df,
    index=["Reg_year", "Reg_month"],
    values="Total_Amount_Spent",
    aggfunc=np.sum,
).plot(kind="line", marker="o", linewidth=2, figsize=(12, 5))
# Out:
# <Axes: xlabel='Reg_year,Reg_month'>

# %% [markdown]
# The plot clearly shows that the total amount spent has declined over the years.
#
# The plot shows the highest increase in the amount spent from August to September 2012.

# %% [markdown]
# ####**Total_Amount_Spent vs Income**

# %%
plt.figure(figsize=(12, 5))
sns.regplot(y=df.Total_Amount_Spent, x=df.Income)
# Out:
# <Axes: xlabel='Income', ylabel='Total_Amount_Spent'>

# %% [markdown]
# From the above graph, we can see that income and the total amount spent have a positive correlation.
#
# The total amount spent is not much different for customers with income in the range of 20K to 60K but the difference is significant for customers in the range of 60K to 100K.

# %% [markdown]
# ####**Correlation Check**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Drop non-numeric columns before calculating the correlation matrix
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()

# Plotting the heatmap
plt.figure(figsize=(14, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# From the above Correlation Analysis Graph, we can see:

# %% [markdown]
# 1.   There is a **0.71** correlation between column 'NumCatalogPurchases' and 'MntMeatProducts'. This implies that customers who make more catalog purchases are likely to spend more on meat products. These 2 variables have a very positive linear relationship.
#
# 2.   There is a **0.68** correlation between column 'MntWines' and 'NumCatalogPurchases', 'NumStorePurchases'. This implies that customers purchase wine equally from both the stores and catalogues. These 3 variables have a relatively positive linear relationship.
#
# 3.   There is a **0.69** correlation between column 'Income' and 'MntWines'. This implies that the 2 variables are relatively correlated meaning as the income increases, the purchase of wine will also increase. This can also mean that the product category 'Wine' can be treated as a luxury item.
#
# 4. We see the same correlation of **0.69** correlation between column 'Income' and 'MntMeatProducts'. This shows that similar to wine, the amount of purchases for meat products increase as the income increases. This shows that both the variables are relatively proportional. This is further backed by the correlation of **0.59** for the columns 'MntMeatProducts' and 'MntWines'.
#
# 5. There is a **0.70** correlation between column 'Income' and 'NumCatalogPurchases'. This implies that the 2 variables are greatly correlated meaning as the income increases, the purchase of catalogues will also increase. This also shows that higher amounts of both meat and wine are purchased through catalogues showing people with higher income purchase catalogues thus further purchasing more expensive products like meat and wine.
#
# 6. A correlation of **0.59** between 'MntFishProducts' and 'MntFruits' indicates a moderately strong positive linear relationship between the amount spent on fish products and the amount spent on fruits. Customers who spend more on fish products are likely to also spend more on fruits. This could indicate certain dietary preferences or shopping habits.
#
# 7. We also see a negative correlation of **-0.65** between 'Income' and 'NumWebVisitsMonth'. This means that they aren't correlated and people from all income groups visit the web for Web Purchases.
#
# 8. There being less than 1% complaints in the past 2 years shows that the column 'Complain' is negatively correlated to all of the columns and isn't proportional.
#
# 9. We see a correlation of **0.45** between column 'Kidhome' and 'NumWebVisitsMonth'. This shows that a great portion of web visits are from kids. Both the variables are relatively proportional.

# %% [markdown]
# Also,

# %% [markdown]
# 1. As expected, age and year of birth have a high negative correlation. We can drop one of them.
#
# 2. Registration month and quarter columns are highly correlated which can be expected as we extracted these columns from the same column.
#
# 3. We can drop one of the columns in a quarter or month as they are almost perfectly correlated.
#
# 4. Total amount spent is correlated with variables they are associated with and hence we can drop this column.
#
# 5. Number of purchases is positively correlated with income which can be expected as customers with higher income might spend more than customers with lower income.

# %% [markdown]
# ####**Comparisons through Visualisations:**

# %% [markdown]
# #####**Total_Amount_Spent vs Education**

# %%
sns.boxplot(y="Total_Amount_Spent", x="Education", data=df, orient="vertical", palette="Set1")
# Out:
# <Axes: xlabel='Education', ylabel='Total_Amount_Spent'>

# %% [markdown]
# From the above graph, we can see the amount spent increases with the increase in education level.
# Customers with graduate-level education spend slightly more than customers with master-level education.

# %% [markdown]
# #####**Total_Amount_Spent vs Marital_status**

# %%
sns.set(rc={"figure.figsize": (10, 7)})
sns.boxplot(y="Total_Amount_Spent", x="Marital_Status", data=df, orient="vertical")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Total_Amount_Spent'>

# %% [markdown]
# We can see that the total amount spent is higher for widowed customers.
# No significant difference in the amount spent by single, married or divorced customers.

# %% [markdown]
# #####**Recency, Age, Income, Total_Amount_Spent**

# %%
cols = df[["Recency", "Age", "Income", "Total_Amount_Spent"]].columns.tolist()
plt.figure(figsize=(10, 10))

for i, variable in enumerate(cols):
    plt.subplot(3, 2, i + 1)
    sns.boxplot(x=df["Response"], y=df[variable], palette="Set1")
    plt.tight_layout()
    plt.title(variable)
plt.show()

# %% [markdown]
# From this, we can see:
#
# Customers with lower recency i.e. less number of days since the last purchase, are more likely to take the offer.
#
# Response does not depend much on age.
#
# Customers with higher income are more likely to take the offer.
#
# Customers who spent more in the last 2 years are more likely to take the offer.

# %% [markdown]
# #####**Education vs Response**

# %%
stacked_barplot(df, "Education", "Response")
# Out:
# Response       0    1   All
# Education
# All         1902  334  2236
# Graduation   974  152  1126
# PhD          384  101   485
# Master       492   79   571
# Basic         52    2    54
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# We can see a clear trend here that customers with higher education are more likely to take the offer.

# %% [markdown]
# #####**Marital_Status vs Response**

# %%
stacked_barplot(df, "Marital_Status", "Response")
# Out:
# Response           0    1   All
# Marital_Status
# All             1902  334  2236
# Married         1284  158  1442
# Single           377  109   486
# Divorced         183   48   231
# Widow             58   19    77
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# We saw earlier that number of married customers is much more than single or divorced but divorced/widow customers are more likely to take the offer.
#
# Single customers are more likely to take the offer than married customers.

# %% [markdown]
# ##### **Kidhome vs Response**

# %%
stacked_barplot(df, "Kidhome", "Response")
# Out:
# Response     0    1   All
# Kidhome
# All       1902  334  2236
# 0         1069  222  1291
# 1          787  110   897
# 2           46    2    48
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# We can see that the number of kids increases, chances of customers taking the offer decreases.
#
# Customers with no kids at home are more likely to take the offer which can be expected as this includes single customers as well.

# %% [markdown]
# #####**Teenhome vs Response**

# %%
stacked_barplot(df, "Teenhome", "Response")
# Out:
# Response     0    1   All
# Teenhome
# All       1902  334  2236
# 0          918  237  1155
# 1          937   92  1029
# 2           47    5    52
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Customers with no teens at home are most likely to take the offer.
#
# Customers with two teens are more likely to take the offer than customers with 1 teenager.

# %% [markdown]
# #####**Reg_year vs Response**

# %%
stacked_barplot(df, "Reg_year", "Response")
# Out:
# Response     0    1   All
# Reg_year
# All       1902  334  2236
# 2013      1025  170  1195
# 2012       362  118   480
# 2014       515   46   561
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Number of customers taking the offer is decreasing each subsequent year.
#
# Let's explore this further for month-wise distribution for each of the year.

# %% [markdown]
# ## **5. Model Selection, Training & Evaluation:**

# %% [markdown]
# ###**5.1. Data Preprocessing for Modeling:**

# %%
data1 = df.copy()

# %% [markdown]
# Dropping birth year and Dt_Customer columns:

# %%
# Dropping birth year and Dt_Customer columns
data1.drop(
    columns=[
        "Year_Birth",
        "Dt_Customer",
        "Reg_quarter",
        "Total_Amount_Spent",
    ],
    inplace=True,
)

# %% [markdown]
# Separating target variable and other variables:

# %%
# Separating target variable and other variables
X = data1.drop(columns="Response")
X = pd.get_dummies(X)

Y = data1["Response"]

# %% [markdown]
# Now, we'll split the data into training, validation and test set respectively.

# %%
# Splitting data into training, validation and test set:
# first we split data into 2 parts, say temporary and test

X_temp, X_test, y_temp, y_test = train_test_split(X, Y, test_size=0.2, random_state=1, stratify=Y)

# then we split the temporary set into train and validation

X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25, random_state=1, stratify=y_temp)


print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (1341, 28) (447, 28) (448, 28)

# %% [markdown]
# ###**5.2. Missing-Value Treatment:**

# %% [markdown]
# We'll use the Simple Imputer library for treating with missing values.

# %% [markdown]
# The **SimpleImputer** class in scikit-learn is used for handling missing values in datasets by imputing them with a specified strategy. It's a straightforward imputation technique that replaces missing values with a constant, the mean, median, or most frequent value along each column.

# %%
# To be used for missing value imputation
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="median")

# %%
# Fit and transform the train data
X_train = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns)

# Transform the validation data
X_val = pd.DataFrame(imputer.transform(X_val), columns=X_train.columns)

# Transform the test data
X_test = pd.DataFrame(imputer.transform(X_test), columns=X_train.columns)

# %%
# Checking that no column has missing values in train or test sets
print(X_train.isna().sum())
print("-" * 30)
print(X_val.isna().sum())
print("-" * 30)
print(X_test.isna().sum())
# Out:
# Income                     0
# Kidhome                    0
# Teenhome                   0
# Recency                    0
# MntWines                   0
# MntFruits                  0
# MntMeatProducts            0
# MntFishProducts            0
# MntSweetProducts           0
# MntGoldProds               0
# NumDealsPurchases          0
# NumWebPurchases            0
# NumCatalogPurchases        0
# NumStorePurchases          0
# NumWebVisitsMonth          0
# Complain                   0
# Age                        0
# Reg_year                   0
# Reg_month                  0
# Reg_week                   0
# Education_Basic            0
# Education_Graduation       0
# Education_Master           0
# Education_PhD              0
# Marital_Status_Divorced    0
# Marital_Status_Married     0
# Marital_Status_Single      0
# Marital_Status_Widow       0
# dtype: int64
# ------------------------------
# Income                     0
# Kidhome                    0
# ...

# %% [markdown]
# ###**5.3. Model Building:**

# %% [markdown]
# Model evaluation Metric: **RECALL**

# %% [markdown]
# Recall, also known as Sensitivity or True Positive Rate, is a model evaluation metric commonly used in binary classification tasks. It measures the ability of a classifier to correctly identify all positive instances (True Positives) out of all actual positive instances (True Positives + False Negatives).

# %%
scorer = metrics.make_scorer(metrics.recall_score)

# %% [markdown]
# We'll create two functions to calculate different metrics and confusion matrix so that we don't have to use the same code repeatedly for each model.

# %%
# defining a function to compute different metrics to check performance of a classification model built using sklearn
def model_performance_classification_sklearn(model, predictors, target):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred)  # to compute Recall
    precision = precision_score(target, pred)  # to compute Precision
    f1 = f1_score(target, pred)  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "Accuracy": acc,
            "Recall": recall,
            "Precision": precision,
            "F1": f1,
        },
        index=[0],
    )

    return df_perf

# %%
def confusion_matrix_sklearn(model, predictors, target):
    """
    To plot the confusion_matrix with percentages

    model: classifier
    predictors: independent variables
    target: dependent variable
    """
    y_pred = model.predict(predictors)
    cm = confusion_matrix(target, y_pred)
    labels = np.asarray(
        [
            ["{0:0.0f}".format(item) + "\n{0:.2%}".format(item / cm.flatten().sum())]
            for item in cm.flatten()
        ]
    ).reshape(2, 2)

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=labels, fmt="")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# Building Initial Models:

# %% [markdown]
# We'll start Data Modeling by building different models using **KFold** and **cross_val_score** and then tune the best model by using **GridSearchCV** and **RandomizedSearchCV**.

# %% [markdown]
# ####**Stratified K-Folds cross-validation:**

# %% [markdown]
# Stratified K-Folds cross-validation provides dataset indices to split data into train/validation sets. Split dataset into k consecutive folds (without shuffling by default) keeping the distribution of both classes in each fold the same as the target variable. After this, each fold is then used once as validation while the k - 1 remaining folds form the training set.

# %%
# %%time


models = []  # Empty list to store all the models

# Appending models into the list
models.append(("Bagging", BaggingClassifier(random_state=1)))
models.append(("Random forest", RandomForestClassifier(random_state=1)))
models.append(("GBM", GradientBoostingClassifier(random_state=1)))
models.append(("Adaboost", AdaBoostClassifier(random_state=1)))
models.append(("dtree", DecisionTreeClassifier(random_state=1)))

results1 = []  # Empty list to store all model's CV scores
names = []  # Empty list to store name of the models

# loop through all models to get the mean cross validated score
print("\n" "Cross-Validation performance on training dataset:" "\n")

for name, model in models:
    kfold = StratifiedKFold(
        n_splits=5, shuffle=True, random_state=1
    )  # Setting number of splits equal to 5
    cv_result = cross_val_score(
        estimator=model, X=X_train, y=y_train, scoring = scorer,cv=kfold
    )
    results1.append(cv_result)
    names.append(name)
    print("{}: {}".format(name, cv_result.mean()))

print("\n" "Validation Performance:" "\n")

for name, model in models:
    model.fit(X_train, y_train)
    scores = recall_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores))
# Out:
# Cross-Validation performance on training dataset:
#
# Bagging: 0.215
# Random forest: 0.195
# GBM: 0.27
# Adaboost: 0.36000000000000004
# dtree: 0.34500000000000003
#
# Validation Performance:
#
# Bagging: 0.2835820895522388
# Random forest: 0.22388059701492538
# GBM: 0.373134328358209
# Adaboost: 0.40298507462686567
# dtree: 0.3582089552238806
# CPU times: user 7.5 s, sys: 19.5 ms, total: 7.52 s
# Wall time: 7.71 s

# %% [markdown]
# Here, setting random state to 1 ensures that the randomness is reproducible each time we run the code again and again.

# %% [markdown]
# These performance values represent the mean (average) performance scores achieved by each model during cross-validation on the training dataset. Cross-validation involves splitting the training dataset into multiple subsets (folds), training the model on several combinations of these subsets, and then averaging the performance scores across these iterations.
#
# * A higher performance score (closer to 1.0) indicates better performance of the model.
#
# * Comparing cross-validation performance with validation performance helps us assess whether the models are overfitting (performing well on training data but not on validation data), underfitting (performing poorly on both training and validation data), or generalizing well to unseen data.
#
# * Models with similar cross-validation and validation performance are likely to generalize well and have lower risk of overfitting.

# %%
# Plotting boxplots for CV scores of all models defined above
fig = plt.figure(figsize=(10, 7))

fig.suptitle("Algorithm Comparison")
ax = fig.add_subplot(111)

plt.boxplot(results1)
ax.set_xticklabels(names)

plt.show()

# %% [markdown]
# From the above graph, we can see that:
#
# * Adaboost is giving the highest cross-validated recall followed by dtree and GBM.
#
# We will now tune Adaboost, dtree, and GBM models to see whether the performance improves or not.

# %% [markdown]
# ####**Hyperparameter Tuning using GridSearchCV & RandomizedSearchCV:**

# %% [markdown]
# We will tune Adaboost, dtree, and GBM models using GridSearchCV and RandomizedSearchCV.
#
# We will also compare the performance and time taken by the two hyperparameter tuning methods - **grid search** and **randomized search**.

# %% [markdown]
# #####**Adaboost**

# %% [markdown]
# GridSearchCV

# %%
# defining model
model = AdaBoostClassifier(random_state=1)

# Parameter grid to pass in GridSearchCV

param_grid = {
    "n_estimators": np.arange(10, 110, 10),
    "learning_rate": [0.1, 0.01, 0.2, 0.05, 1],
    "base_estimator": [
        DecisionTreeClassifier(max_depth=1, random_state=1),
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),
    ],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# Calling GridSearchCV
grid_cv = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scorer, cv=5, n_jobs = -1)

# Fitting parameters in GridSearchCV
grid_cv.fit(X_train, y_train)

print(
    "Best Parameters:{} \nScore: {}".format(grid_cv.best_params_, grid_cv.best_score_)
)
# Out:
# Best Parameters:{'base_estimator': DecisionTreeClassifier(max_depth=2, random_state=1), 'learning_rate': 1, 'n_estimators': 40}
# Score: 0.39

# %%
# building model with best parameters
adb_tuned1 = AdaBoostClassifier(
    n_estimators=30,
    learning_rate=1,
    random_state=1,
    base_estimator=DecisionTreeClassifier(max_depth=2, random_state=1),
)

# Fit the model on training data
adb_tuned1.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=2,
#                                                          random_state=1),
#                    learning_rate=1, n_estimators=30, random_state=1)

# %%
# Calculating different metrics on train set
Adaboost_grid_train = model_performance_classification_sklearn(
    adb_tuned1, X_train, y_train
)
print("Training performance:")
Adaboost_grid_train
# Out:
# Training performance:
#    Accuracy  Recall  Precision    F1
# 0     0.931   0.675      0.833 0.746

# %%
# Calculating different metrics on validation set
Adaboost_grid_val = model_performance_classification_sklearn(adb_tuned1, X_val, y_val)
print("Validation performance:")
Adaboost_grid_val
# Out:
# Validation performance:
#    Accuracy  Recall  Precision    F1
# 0     0.857   0.343      0.535 0.418

# %%
# creating confusion matrix
confusion_matrix_sklearn(adb_tuned1, X_val, y_val)

# %% [markdown]
# * The validation recall is similar to cross-validated recall
# * The tuned Adaboost model is overfitting the training data
# * The validation recall is still less than 50% i.e. the model is not good at identifying potential customers who would take the offer.

# %% [markdown]
# RandomizedSearchCV

# %%
# defining model
model = AdaBoostClassifier(random_state=1)

# Parameter grid to pass in RandomizedSearchCV

param_grid = {
    "n_estimators": np.arange(10, 110, 10),
    "learning_rate": [0.1, 0.01, 0.2, 0.05, 1],
    "base_estimator": [
        DecisionTreeClassifier(max_depth=1, random_state=1),
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),
    ],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_jobs = -1, n_iter=50, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train,y_train)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 50, 'learning_rate': 1, 'base_estimator': DecisionTreeClassifier(max_depth=2, random_state=1)} with CV score=0.385:

# %%
# building model with best parameters
adb_tuned2 = AdaBoostClassifier(
    n_estimators=20,
    learning_rate=1,
    random_state=1,
    base_estimator=DecisionTreeClassifier(max_depth=3, random_state=1),
)

# Fit the model on training data
adb_tuned2.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=3,
#                                                          random_state=1),
#                    learning_rate=1, n_estimators=20, random_state=1)

# %%
# Calculating different metrics on train set
Adaboost_random_train = model_performance_classification_sklearn(
    adb_tuned2, X_train, y_train
)
print("Training performance:")
Adaboost_random_train
# Out:
# Training performance:
#    Accuracy  Recall  Precision    F1
# 0     0.975   0.870      0.956 0.911

# %%
# Calculating different metrics on validation set
Adaboost_random_val = model_performance_classification_sklearn(adb_tuned2, X_val, y_val)
print("Validation performance:")
Adaboost_random_val
# Out:
# Validation performance:
#    Accuracy  Recall  Precision    F1
# 0     0.872   0.463      0.596 0.521

# %%
# creating confusion matrix
confusion_matrix_sklearn(adb_tuned2, X_val, y_val)

# %% [markdown]
# * Grid search took a significantly longer time than random search. This difference would further increase as the number of parameters increases.
#
# * The results from both grid and random search are similar.

# %% [markdown]
# #####**Decision Tree**

# %% [markdown]
# GridsearchCV

# %%
# Choose the type of classifier.
dtree_estimator = DecisionTreeClassifier(random_state=1)

# Grid of parameters to choose from
parameters = {
    "max_depth": np.arange(10, 30, 5),
    "min_samples_leaf": [3, 5, 7],
    "max_leaf_nodes": [2, 3, 5],
    "min_impurity_decrease": [0.0001, 0.001],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

#Calling GridSearchCV
grid_cv = GridSearchCV(estimator=dtree_estimator, param_grid=parameters, scoring=scorer, cv=5, n_jobs = -1)

#Fitting parameters in GridSearchCV
grid_cv.fit(X_train,y_train)


print("Best parameters are {} with CV score={}:" .format(grid_cv.best_params_,grid_cv.best_score_))
# Out:
# Best parameters are {'max_depth': 10, 'max_leaf_nodes': 5, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 3} with CV score=0.15499999999999997:

# %%
# building model with best parameters
dt_tuned_grid = DecisionTreeClassifier(
     max_depth= 10,
    min_samples_leaf= 3,
    max_leaf_nodes= 5,
    min_impurity_decrease= 0.0001,
)

# Fit the model on training data
dt_tuned_grid.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, max_leaf_nodes=5,
#                        min_impurity_decrease=0.0001, min_samples_leaf=3)

# %%
dt_grid_train = model_performance_classification_sklearn(
    dt_tuned_grid, X_train, y_train
)
dt_grid_train
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.853   0.165      0.524 0.251

# %%
dt_grid_val = model_performance_classification_sklearn(
    dt_tuned_grid, X_val, y_val
)
dt_grid_val
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.841   0.119      0.400 0.184

# %%
confusion_matrix_sklearn(dt_tuned_grid, X_train, y_train)

# %% [markdown]
# The validation recall is still less than 50% i.e. the model is not good at identifying potential customers who would take the offer.

# %% [markdown]
# RandomSearchCV

# %%
# defining model
model = DecisionTreeClassifier(random_state=1)


# Parameter grid to pass in RandomSearchCV
param_grid = {
    "max_depth": np.arange(2, 6),
    "min_samples_leaf": [1,2,3, 4, 7],
    "max_leaf_nodes": [10, 15,20],
    "min_impurity_decrease": [0.0001, 0.001],
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_jobs = -1, n_iter=50, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train,y_train)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'min_samples_leaf': 2, 'min_impurity_decrease': 0.001, 'max_leaf_nodes': 15, 'max_depth': 5} with CV score=0.28500000000000003:

# %%
# building model with best parameters
dt_tuned = DecisionTreeClassifier(
     max_depth= 5,
    min_samples_leaf= 2,
    max_leaf_nodes= 15,
    min_impurity_decrease= 0.001,
)

# Fit the model on training data
dt_tuned.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, max_leaf_nodes=15,
#                        min_impurity_decrease=0.001, min_samples_leaf=2)

# %%
## To check the performance on training set
dt_random_train = model_performance_classification_sklearn(
    dt_tuned, X_train, y_train
)
dt_random_train
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.884   0.365      0.716 0.483

# %%
## To check the performance on validation set
dt_random_val = model_performance_classification_sklearn(
    dt_tuned, X_val, y_val
)
dt_random_val
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.841   0.179      0.429 0.253

# %% [markdown]
# * We have received the recall score of 0.365 and 0.179 on the training and the test set, respectively.
#
# * Model is not generalizing well on both the train and validation dataset

# %% [markdown]
# #####**Gradient Boosting Machine (GBM)**

# %% [markdown]
# GridSearchCV

# %%
# defining model
Model = GradientBoostingClassifier(random_state=1)

#Parameter grid to pass in GridSearchCV
param_grid={
            "n_estimators": np.arange(25,100,25),
            "learning_rate": [0.2,0.01, 0.05, 1],
            "subsample":[0.2,0.3,0.4,0.5],
            "max_features":[0.5,0.6,0.7,0.8]}

#Calling GridSearchCV
grid_cv = GridSearchCV(estimator=Model, param_grid=param_grid, scoring=scorer, n_jobs = -1, cv=5)

#Fitting parameters in GridSearchCV
grid_cv.fit(X_train, y_train)

print("Best parameters are {} with CV score={}:" .format(grid_cv.best_params_,grid_cv.best_score_))
# Out:
# Best parameters are {'learning_rate': 1, 'max_features': 0.5, 'n_estimators': 50, 'subsample': 0.3} with CV score=0.5650000000000001:

# %%
# Creating new pipeline with best parameters
tuned_gbm1 = GradientBoostingClassifier(
    max_features=0.7,
    random_state=1,
    learning_rate=1,
    n_estimators=50,
    subsample=0.2
)

tuned_gbm1.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=1, max_features=0.7, n_estimators=50,
#                            random_state=1, subsample=0.2)

# %%
gbm_grid_train = model_performance_classification_sklearn(
    tuned_gbm1, X_train, y_train
)
gbm_grid_train
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.272   0.825      0.149 0.253

# %%
gbm_grid_val = model_performance_classification_sklearn(tuned_gbm1, X_val, y_val)
gbm_grid_val
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.293   0.791      0.149 0.251

# %% [markdown]
# Here, the GBM model on gridsearchCV generalizing well on both train and validation datasets.
#
# The validation recall is ~85% i.e. the model is good at identifying potential customers who would take the offer.

# %% [markdown]
# RandomSearchCV

# %%
# defining model
Model = GradientBoostingClassifier(random_state=1)

#Parameter grid to pass in RandomSearchCV
param_grid={
            "n_estimators": np.arange(50,150,25),
            "learning_rate": [0.2,0.01, 0.05, 1],
            "subsample":[0.3,0.4,0.5,0.7,0.6],
            "max_features":[0.3,0.4,0.5,0.6,0.7]
}

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, scoring=scorer, n_iter=50, n_jobs = -1, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train, y_train)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'subsample': 0.3, 'n_estimators': 75, 'max_features': 0.7, 'learning_rate': 1} with CV score=0.54:

# %%
# Creating new pipeline with best parameters
tuned_gbm = GradientBoostingClassifier(
    max_features=0.7,
    random_state=1,
    learning_rate=1,
    n_estimators=75,
    subsample=0.3
)

tuned_gbm.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=1, max_features=0.7, n_estimators=75,
#                            random_state=1, subsample=0.3)

# %%
gbm_random_train= model_performance_classification_sklearn(
    tuned_gbm, X_train, y_train
)
gbm_random_train
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.755   0.595      0.325 0.420

# %%
gbm_random_val = model_performance_classification_sklearn(tuned_gbm, X_val, y_val)
gbm_random_val
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.734   0.433      0.264 0.328

# %% [markdown]
# * We have received the Recall score of 0.63 and 0.43 on the training and the test set, respectively.
# * After tuning the hyperparameters the GBM model is still overfitting. There's a big difference in the training and the validation recall.

# %% [markdown]
# ###**5.4. Model Performance Comparison and Final Model Selection**

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [
        Adaboost_grid_train.T,
        Adaboost_random_train.T,
        gbm_grid_train.T,
        gbm_random_train.T,
        dt_grid_train.T,
        dt_random_train.T
    ],
    axis=1,
)
models_train_comp_df.columns = [
    "AdaBoost Tuned with Grid search",
    "AdaBoost Tuned with Random search",
    "Gradient Boosting Tuned with Grid search",
    "Gradient Boosting Tuned with Random search",
    "Decision tree with grid search",
    "Decision tree with random search",
]
print("Training performance comparison:")
models_train_comp_df
# Out:
# Training performance comparison:
#            AdaBoost Tuned with Grid search  AdaBoost Tuned with Random search  \
# Accuracy                             0.931                              0.975
# Recall                               0.675                              0.870
# Precision                            0.833                              0.956
# F1                                   0.746                              0.911
#
#            Gradient Boosting Tuned with Grid search  \
# Accuracy                                      0.272
# Recall                                        0.825
# Precision                                     0.149
# F1                                            0.253
#
#            Gradient Boosting Tuned with Random search  \
# Accuracy                                        0.755
# Recall                                          0.595
# Precision                                       0.325
# F1                                              0.420
#
# ...

# %% [markdown]
# ####**AdaBoost Tuned with Grid Search**

# %%
import matplotlib.pyplot as plt

x = [0.931, 0.675, 0.833, 0.746]
y = ["Accuracy", "Recall", "Precision", "F1"]

plt.figure(figsize=(8, 6))
plt.barh(y, x, color='skyblue')
plt.xlabel('Score')
plt.title('Performance Metrics')

# Display the values on the bars
for i, v in enumerate(x):
    plt.text(v, i, f' {v}', va='center')

plt.show()

# %% [markdown]
# ####**AdaBoost Tuned with Random Search**

# %%
import matplotlib.pyplot as plt

x = [0.975, 0.870, 0.956, 0.911]
y = ["Accuracy", "Recall", "Precision", "F1"]

plt.figure(figsize=(8, 6))
plt.barh(y, x, color='blue')
plt.xlabel('Score')
plt.title('Performance Metrics')

# Display the values on the bars
for i, v in enumerate(x):
    plt.text(v, i, f' {v}', va='center')

plt.show()

# %% [markdown]
# ####**GradientBoosting Tuned with Grid Search**

# %%
import matplotlib.pyplot as plt

x = [0.272, 0.825, 0.149, 0.253]
y = ["Accuracy", "Recall", "Precision", "F1"]

plt.figure(figsize=(8, 6))
plt.barh(y, x, color='lightgreen')
plt.xlabel('Score')
plt.title('Performance Metrics')

# Display the values on the bars
for i, v in enumerate(x):
    plt.text(v, i, f' {v}', va='center')

plt.show()

# %% [markdown]
# ####**GradientBoosting Tuned with Random Search**

# %%
import matplotlib.pyplot as plt

x = [0.755, 0.595, 0.325, 0.420]
y = ["Accuracy", "Recall", "Precision", "F1"]

plt.figure(figsize=(8, 6))
plt.barh(y, x, color='green')
plt.xlabel('Score')
plt.title('Performance Metrics')

# Display the values on the bars
for i, v in enumerate(x):
    plt.text(v, i, f' {v}', va='center')

plt.show()

# %% [markdown]
# ####**Decision Tree with Grid Search**

# %%
import matplotlib.pyplot as plt

x = [0.853, 0.165, 0.524, 0.251]
y = ["Accuracy", "Recall", "Precision", "F1"]

plt.figure(figsize=(8, 6))
plt.barh(y, x, color='red')
plt.xlabel('Score')
plt.title('Performance Metrics')

# Display the values on the bars
for i, v in enumerate(x):
    plt.text(v, i, f' {v}', va='center')

plt.show()

# %% [markdown]
# ####**Decision Tree with Random Search**

# %%
import matplotlib.pyplot as plt

x = [0.884,0.365,0.716,0.483]
y = ["Accuracy", "Recall", "Precision", "F1"]

plt.figure(figsize=(8, 6))
plt.barh(y, x, color='purple')
plt.xlabel('Score')
plt.title('Performance Metrics')

# Display the values on the bars
for i, v in enumerate(x):
    plt.text(v, i, f' {v}', va='center')

plt.show()

# %% [markdown]
# ###**Findings**:

# %% [markdown]
# The Gradient Boosting(GBM) model tuned using Grid search is giving the best validation recall of 0.85 but it has the low values of train and validation precision.
#
# Let's check the model's performance on test set and then see the feature importance from the tuned GBM model

# %%
# Calculating different metrics on the test set
gbm_grid_test = model_performance_classification_sklearn(tuned_gbm1, X_test, y_test)
print("Test performance:")
gbm_grid_test
# Out:
# Test performance:
#    Accuracy  Recall  Precision    F1
# 0     0.306   0.910      0.167 0.282

# %% [markdown]
# The performance on test data is generalised.
# Let's check the important features for prediction as per the the final model.

# %% [markdown]
# ###**5.5. Feature Importance**

# %%
feature_names = X.columns
importances = tuned_gbm1.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(12, 12))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], color="violet", align="center")
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# From the above graph, we can see the amount spent on NumCatalogPurchases is the most important feature, followed by Recency and MntMeatProducts.

# %% [markdown]
# ###**5.6. Pipelines**

# %% [markdown]
# Pipelines in machine learning are a way to streamline and automate the process of building and evaluating complex machine learning workflows.
#
# Now that we have a final model, let's use pipelines to put the model into production. We know that we can use pipelines to standardize the model building, but the steps in a pipeline are applied to each and every variable.
#
# By using **Column Transformer** we can personalize the pipeline to perform different preprocessing steps on different columns

# %% [markdown]
# **Column Transformer**
#
# Column Transformer allows different columns or column subsets of the input to be transformed separately and the features generated by each transformer will be concatenated to form a single feature space.
#
# This is useful for heterogeneous or columnar data to combine several feature extraction mechanisms or transformations into a single transformer

# %% [markdown]
# Here, we will create 2 different pipelines, one for numerical columns and one for categorical columns.
#
# For numerical columns, we will do missing value imputation as pre-processing
# For categorical columns, we will do one hot encoding and missing value imputation as pre-processing.

# %% [markdown]
# We will be also doing missing value imputation for the whole data so that any missing values' occurence in the future can be taken care of.

# %%
# creating a list of numerical variables
numerical_features = [
    "Income",
    "Kidhome",
    "Teenhome",
    "Recency",
    "MntWines",
    "MntFruits",
    "MntMeatProducts",
    "MntFishProducts",
    "MntSweetProducts",
    "MntGoldProds",
    "NumDealsPurchases",
    "NumWebPurchases",
    "NumCatalogPurchases",
    "NumStorePurchases",
    "NumWebVisitsMonth",
    "Complain",
    "Age",
    "Reg_year",
    "Reg_month",
    "Reg_week",
]

# creating a transformer for numerical variables, which will apply simple imputer on the numerical variables
numeric_transformer = Pipeline(steps=[("imputer", SimpleImputer(strategy="median"))])


# creating a list of categorical variables
categorical_features = ["Education", "Marital_Status"]

# creating a transformer for categorical variables, which will first apply simple imputer and
#then do one hot encoding for categorical variables
categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown="ignore")),
    ]
)
# handle_unknown = "ignore", allows model to handle any unknown category in the test data

# combining categorical transformer and numerical transformer using a column transformer

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numerical_features),
        ("cat", categorical_transformer, categorical_features),
    ],
    remainder="passthrough",
)
# remainder = "passthrough" has been used, it will allow variables that are present in original data
# but not in "numerical_columns" and "categorical_columns" to pass through the column transformer without any changes

# %%
# Separating target variable and other variables
X = data1.drop(columns="Response")
Y = data1["Response"]

# %% [markdown]
# because we already know the best model we need to process with, we don't need to divide data into 3 parts.

# %%
# Splitting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=1, stratify=Y
)
print(X_train.shape, X_test.shape)
# Out:
# (1788, 22) (448, 22)

# %%
# Creating new pipeline with best parameters
model = Pipeline(
    steps=[
        ("pre", preprocessor),
        (
            "GBM",
            GradientBoostingClassifier(
            max_features=0.7,
            random_state=1,
            learning_rate=1,
            n_estimators=50,
            subsample=0.2
        ),
        ),
    ]
)
# Fit the model on training data
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Income', 'Kidhome',
#                                                    'Teenhome', 'Recency',
#                                                    'MntWines', 'MntFruits',
#                                                    'MntMeatProducts',
#                                                    'MntFishProducts',
#                                                    'MntSweetProducts',
#                                                    'MntGoldProds',
#                                                    'NumDealsPurchases',
#                                                    'NumWebPurchases',
# ...

# %%
# Let's check the performance on test set
Model_test = model_performance_classification_sklearn(model, X_test, y_test)
Model_test
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.719   0.552      0.278 0.370

# %% [markdown]
# ##**6. Insights**

# %% [markdown]
# 1. The Total amount spent has decreased over the years, which shows that either the quality of products has declined or the company lacks marketing strategies
#
#   The company should constantly improve its marketing strategies to address such issues.
#
# 2. Our analysis showed that ~99% of customers had no complaints in the last two years, which can be due to the lack of feedback options for customers.
#
#   The company should create easy mechanisms to gather feedback from the customers and use it to identify major concerns if any.
#
# 3. The company should target customers who buy premium products - gold products or high-quality wines - as these customers can spend more and are more likely to purchase the offer.
#
#   The company should further launch premium offers for such customers.
#
#   Such offers can also be extended to customers with higher income.
#
# 4. The number of web visits is an important feature and the company should work on customizing its website to direct more traffic to the website.
#   The company can improve the interface and provide easy check-in, check-out, and delivery options
#
# 5. Customers who are frequent buyers should be targeted more by the company and offered added benefits.
